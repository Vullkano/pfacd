# %%
import numpy as np
from pyprojroot.here import here
import pandas as pd
from pyarrow import feather
import janitor
from janitor import clean_names

groups = {
  "populacao": ["densidade_populacional", "populacao_residente"],
  "setor": [["setor_primario", "setor_secundario", "setor_terciario"], ["perc_prim", "perc_sec"]],
  "causas": ["classe_da_causa_6", "causa_do_incidente", "classe_da_causa_4"],
  "direcao do vento" : [["dd_med", "dd_ffx"], ["dd_med_sin", "dd_med_cos", "dd_ffx_sin", "dd_ffx_cos"]],

  # TODO falta aquilo da altitude e tal
}
variables_to_not_use = ["codigo_do_relatorio", "distrito", "perc_terc"]


# import data/EventosSemAltitudeETal.feather
df = feather.read_feather(here("data/EventosSemAltitudeETal.feather"))
df = clean_names(df)
df
# Out:
#      codigo_do_relatorio           concelho data_do_incidente nivel_de_tensao  \
# 0      EDPD_2018_JAN_T_1             ALMADA        2018-01-02              MT
# 1      EDPD_2018_JAN_T_2              SERTA        2018-01-02              MT
# 2      EDPD_2018_JAN_T_3         FELGUEIRAS        2018-01-04              MT
# 3      EDPD_2018_JAN_T_4      TORRES-VEDRAS        2018-01-05              BT
# 4      EDPD_2018_JAN_T_5               NISA        2018-01-09              MT
# ...                  ...                ...               ...             ...
# 2917  EDPD_2020_DEZ_T_21             POMBAL        2020-12-24              MT
# 2918  EDPD_2020_DEZ_T_22  VILA-NOVA-DE-GAIA        2020-12-30              MT
# 2919  EDPD_2020_DEZ_T_23          ALBUFEIRA        2020-12-28              MT
# 2920  EDPD_2020_DEZ_T_24       CASTRO-MARIM        2020-12-28              MT
# 2921  EDPD_2020_DEZ_T_25            OURIQUE        2020-12-29              MT
#
#           causa_do_incidente duracao_incidente_min_  n_º_clientes_afetados  \
# 0                 Escavações                     55                    828
# 1           Abate De Árvores                    163                    549
# 2     Deslizamento De Terras                    596                   3459
# 3                   Veículos                    178                    102
# 4                       Aves                    119                   1731
# ...                      ...                    ...                    ...
# 2917        Abate De Árvores                    139                   2517
# 2918                    Aves                     81                   3641
# 2919              Escavações                     81                   3175
# 2920                Veículos                    239                    591
# 2921                    Aves                    129                      1
#
#       tiepi_mt_min_  saifi_mt_#_  saidi_mt_min_  ...   sen_mes   cos_mes  \
# 0          0.002935     0.000044       0.002456  ...  0.207912  0.978148
# 1          0.002933     0.000177       0.016501  ...  0.207912  0.978148
# 2          0.019228     0.000266       0.035905  ...  0.207912  0.978148
# 3          0.000000     0.000000       0.000000  ...  0.207912  0.978148
# 4          0.004422     0.000155       0.010038  ...  0.207912  0.978148
# ...             ...          ...            ...  ...       ...       ...
# 2917       0.005941     0.000461       0.017245  ...  0.587785 -0.809017
# 2918       0.011914     0.000290       0.011131  ...  0.587785 -0.809017
# 2919       0.005974     0.000086       0.005940  ...  0.587785 -0.809017
# 2920       0.006928     0.000054       0.011528  ...  0.587785 -0.809017
# 2921       0.000394     0.000011       0.001386  ...  0.587785 -0.809017
#
#       t_med  t_max   t_min  dd_med  dd_ffx  ff_med  ff_max     pr_qtd
# 0     10.70  17.40   2.600  278.25  289.50     2.0   7.800   0.000000
# 1     10.60  13.80   6.200  249.00  270.00     2.8   8.100   0.000000
# 2     14.00  14.80  12.900  197.00  180.00     3.9  14.400   4.000000
# 3     12.40  15.10   9.100  288.00  225.00     3.6  13.900  13.200000
# 4      4.90   7.80   2.200  137.00  118.00     4.1  15.400  15.900000
# ...     ...    ...     ...     ...     ...     ...     ...        ...
# 2917   7.90  12.20   2.100    7.00  351.00     1.7   7.600   0.000000
# 2918   4.45   9.05   0.275  239.00  186.25     1.5   4.825   0.787500
# 2919  13.20  15.30   7.700  285.00  293.00     5.8  14.100   0.100000
# 2920  13.20  15.30   7.700  285.00  293.00     5.8  14.100   0.100000
# 2921   7.40  12.40   3.400  280.00  344.00     3.9   9.500   0.766667
#
# [2922 rows x 48 columns]

# %%
from skimpy import skim
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 2922   │ │ float64     │ 29    │ │ concelho              │                                │
# │ │ Number of columns │ 48     │ │ int32       │ 9     │ │ nivel_de_tensao       │                                │
# │ └───────────────────┴────────┘ │ category    │ 6     │ │ causa_do_incidente    │                                │
# │                                │ string      │ 3     │ │ decisao               │                                │
# │                                │ datetime64  │ 1     │ │ classe_da_causa_4     │                                │
# │                                └─────────────┴───────┘ │ classe_da_causa_6     │                                │
# │                                                        └───────────────────────┘                                │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA ┃ NA % ┃ mean    ┃ sd     ┃ p0     ┃ p25     ┃ p50     ┃ p75     ┃ p100    ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━┩  │
# │ │ n_º_clientes_afet │  0 │    0 │    3300 │  36000 │      1 │     380 │    1500 │    2800 │ 1700000 │   ▇    │  │
# │ │ ados              │    │      │         │        │        │         │         │         │         │        │  │
# │ │ tiepi_mt_min_     │  0 │    0 │   0.057 │    1.5 │      0 │  0.0026 │  0.0067 │   0.013 │      58 │   ▇    │  │
# │ │ saifi_mt_#_       │  0 │    0 │  0.0012 │  0.031 │      0 │   6e-05 │ 0.00017 │ 0.00032 │     1.5 │   ▇    │  │
# │ │ saidi_mt_min_     │  0 │    0 │    0.07 │    1.9 │      0 │  0.0033 │   0.012 │   0.023 │      96 │   ▇    │  │
# │ │ end_mwh_          │  0 │    0 │       1 │    4.3 │      0 │    0.18 │    0.47 │    0.95 │     140 │   ▇    │  │
# │ │ saifi_bt_#_       │  0 │    0 │ 0.00055 │  0.011 │      0 │ 2.5e-05 │ 0.00011 │ 0.00025 │    0.53 │   ▇    │  │
# │ │ saidi_bt_min_     │  0 │    0 │   0.081 │    2.2 │      0 │  0.0019 │   0.007 │   0.016 │      86 │   ▇    │  │
# │ │ densidade_populac │  0 │    0 │     630 │   1400 │    4.8 │      36 │     110 │     400 │    7300 │   ▇    │  │
# │ │ ional             │    │      │         │        │        │         │         │         │         │        │  │
# │ │ populacao_residen │  0 │    0 │   77000 │ 110000 │   1600 │   14000 │   37000 │   81000 │  560000 │   ▇▁   │  │
# │ │ te                │    │      │         │        │        │         │         │         │         │        │  │
# │ │ setor_primario    │  0 │    0 │     620 │    590 │     33 │     310 │     490 │     770 │    5800 │   ▇▁   │  │
# │ │ setor_secundario  │  0 │    0 │    6800 │   7800 │    100 │    1400 │    3600 │    9700 │   34000 │  ▇▂▁▁  │  │
# │ │ setor_terciario   │  0 │    0 │   26000 │  44000 │    390 │    3700 │   10000 │   24000 │  220000 │   ▇▁   │  │
# │ │ indice_de_envelhe │  0 │    0 │     230 │    100 │     95 │     160 │     200 │     260 │     810 │  ▇▅▁   │  │
# │ │ cimento           │    │      │         │        │        │         │         │         │         │        │  │
# │ │ rural             │  0 │    0 │     0.7 │   0.41 │      0 │    0.51 │       1 │       1 │       1 │ ▃   ▁▇ │  │
# │ │ count_zonaa       │  0 │    0 │      59 │    170 │      0 │       0 │       0 │      41 │     880 │   ▇    │  │
# │ │ count_zonab       │  0 │    0 │      19 │     34 │      0 │       0 │       8 │      23 │     250 │   ▇▁   │  │
# │ │ count_zonac       │  0 │    0 │      17 │     17 │      0 │       6 │      13 │      23 │     110 │  ▇▃▁▁  │  │
# │ │ total_concelho_zo │  0 │    0 │      95 │    170 │      1 │      15 │      38 │      89 │     880 │   ▇▁   │  │
# │ │ nas               │    │      │         │        │        │         │         │         │         │        │  │
# │ │ percentagem_zonaa │  0 │    0 │     0.2 │   0.34 │      0 │       0 │       0 │    0.32 │       1 │ ▇   ▁▁ │  │
# │ │ percentagem_zonab │  0 │    0 │    0.31 │   0.31 │      0 │       0 │    0.27 │    0.58 │       1 │ ▇▃▂▃▂▁ │  │
# │ │ percentagem_zonac │  0 │    0 │    0.49 │   0.34 │      0 │    0.21 │    0.43 │    0.81 │       1 │ ▇▆▆▃▃▇ │  │
# │ │ soma_degree_rede_ │  0 │    0 │     9.3 │     25 │      0 │    0.25 │       2 │       6 │     130 │   ▇    │  │
# │ │ concelho          │    │      │         │        │        │         │         │         │         │        │  │
# │ │ n_subestacoes_con │  0 │    0 │     3.4 │    4.8 │      0 │       1 │       2 │       4 │      26 │   ▇▁   │  │
# │ │ celho             │    │      │         │        │        │         │         │         │         │        │  │
# │ │ perc_prim         │  0 │    0 │   0.058 │  0.065 │ 0.0024 │   0.014 │   0.034 │   0.074 │     0.4 │  ▇▂▁   │  │
# │ │ perc_sec          │  0 │    0 │    0.25 │   0.11 │  0.089 │    0.17 │    0.23 │    0.32 │     0.6 │ ▇▇▅▃▂  │  │
# │ │ perc_terc         │  0 │    0 │    0.69 │   0.11 │   0.38 │    0.62 │    0.68 │    0.77 │    0.91 │  ▃▅▇▆▃ │  │
# │ │ sen_ano           │  0 │    0 │   -0.22 │  0.029 │  -0.26 │   -0.25 │   -0.21 │    -0.2 │   -0.18 │ ▆▆▇▇▆▇ │  │
# │ │ cos_ano           │  0 │    0 │   -0.98 │ 0.0065 │  -0.98 │   -0.98 │   -0.98 │   -0.97 │   -0.96 │ ▇▆▇▇▆▆ │  │
# │ │ sen_mes           │  0 │    0 │    0.75 │   0.23 │   0.21 │    0.59 │    0.87 │    0.95 │    0.99 │ ▁▁▃ ▃▇ │  │
# │ │ cos_mes           │  0 │    0 │    0.25 │   0.57 │  -0.81 │   -0.31 │    0.31 │    0.81 │    0.98 │ ▃▅▂▅▅▇ │  │
# │ │ t_med             │  0 │    0 │      16 │    5.4 │      0 │      12 │      16 │      20 │      35 │  ▅▇▇▂  │  │
# │ │ t_max             │  0 │    0 │      22 │      7 │      3 │      16 │      21 │      26 │      44 │  ▆▇▅▂  │  │
# │ │ t_min             │  0 │    0 │      11 │    4.9 │   -5.5 │     8.1 │      12 │      15 │      30 │  ▃▇▇▁  │  │
# │ │ dd_med            │  0 │    0 │     210 │    110 │      0 │     140 │     240 │     300 │     360 │ ▅▃▃▅▇▇ │  │
# │ │ dd_ffx            │  0 │    0 │     230 │     99 │      0 │     170 │     260 │     310 │     360 │ ▂▂▂▅▆▇ │  │
# │ │ ff_med            │  0 │    0 │       3 │    1.5 │    0.1 │       2 │     2.8 │     3.8 │      14 │  ▆▇▁   │  │
# │ │ ff_max            │  0 │    0 │      10 │    3.8 │    0.6 │     7.6 │     9.5 │      12 │      33 │  ▁▇▃▁  │  │
# │ │ pr_qtd            │  0 │    0 │     3.4 │    8.4 │      0 │       0 │       0 │     2.5 │     150 │   ▇    │  │
# │ └───────────────────┴────┴──────┴─────────┴────────┴────────┴─────────┴─────────┴─────────┴─────────┴────────┘  │
# │                                                    category                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                                 ┃ NA      ┃ NA %         ┃ ordered            ┃ unique         ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩  │
# │ │ concelho                                    │       0 │            0 │ False              │            256 │  │
# │ │ nivel_de_tensao                             │       0 │            0 │ True               │              3 │  │
# │ │ causa_do_incidente                          │       0 │            0 │ False              │             19 │  │
# │ │ decisao                                     │       0 │            0 │ False              │              2 │  │
# │ │ classe_da_causa_4                           │       0 │            0 │ False              │              4 │  │
# │ │ classe_da_causa_6                           │       0 │            0 │ False              │              6 │  │
# │ └─────────────────────────────────────────────┴─────────┴──────────────┴────────────────────┴────────────────┘  │
# │                                                    datetime                                                     │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                   ┃ NA    ┃ NA %     ┃ first             ┃ last              ┃ frequency       ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩  │
# │ │ data_do_incidente             │     0 │        0 │    2018-01-02     │    2023-12-30     │ None            │  │
# │ └───────────────────────────────┴───────┴──────────┴───────────────────┴───────────────────┴─────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                           ┃ NA    ┃ NA %      ┃ words per row            ┃ total words         ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ codigo_do_relatorio                   │     0 │         0 │                        1 │                2922 │  │
# │ │ duracao_incidente_min_                │     0 │         0 │                        1 │                2922 │  │
# │ │ distrito                              │     0 │         0 │                        1 │                2922 │  │
# │ └───────────────────────────────────────┴───────┴───────────┴──────────────────────────┴─────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
# use as test data 2023
test_data = df[df.data_do_incidente.dt.year == 2023]
train_data = df[df.data_do_incidente.dt.year != 2023]
test_data
# Out:
#        codigo_do_relatorio           concelho data_do_incidente  \
# 1529   EREDES_2023_JAN_T_1           BARCELOS        2023-01-02
# 1530  EREDES_2023_JAN_TC_1           LOURINHA        2023-01-01
# 1531   EREDES_2023_JAN_T_2            ODEMIRA        2023-01-07
# 1532   EREDES_2023_JAN_T_3              PORTO        2023-01-01
# 1533   EREDES_2023_JAN_T_4  SANTIAGO-DO-CACEM        2023-01-01
# ...                    ...                ...               ...
# 1938  EREDES_2023_DEZ_T_11  SANTIAGO-DO-CACEM        2023-12-27
# 1939  EREDES_2023_DEZ_T_12               MORA        2023-12-28
# 1940  EREDES_2023_DEZ_T_13             FUNDAO        2023-12-27
# 1941  EREDES_2023_DEZ_T_14           LOURINHA        2023-12-30
# 1942  EREDES_2023_DEZ_T_15            CARTAXO        2023-12-29
#
#      nivel_de_tensao             causa_do_incidente duracao_incidente_min_  \
# 1529              MT                         Furtos                    330
# 1530              AT  Vento Intensidade Excepcional                    780
# 1531              MT                           Aves                     94
# 1532              BT       Inundações Imprevisíveis                    239
# 1533              MT                           Aves                    297
# ...              ...                            ...                    ...
# 1938              MT                       Veículos                    208
# 1939              BT                         Furtos                    722
# 1940              MT                           Aves                    142
# 1941              MT               Abate De Árvores                    322
# 1942              MT               Abate De Árvores                    158
#
#       n_º_clientes_afetados  tiepi_mt_min_  saifi_mt_#_  saidi_mt_min_  ...  \
# 1529                   3676       0.053320     0.000480       0.077890  ...
# 1530                  77213       0.560000     0.014000       0.842000  ...
# 1531                    743       0.002510     0.000130       0.008360  ...
# 1532                     79       0.000000     0.000000       0.000000  ...
# 1533                    199       0.012420     0.000170       0.026260  ...
# ...                     ...            ...          ...            ...  ...
# 1938                   2169       0.014931     0.000567       0.029906  ...
# 1939                     13       0.001084     0.000010       0.007582  ...
# 1940                   2348       0.006305     0.000661       0.015852  ...
# 1941                   2097       0.022287     0.000157       0.034820  ...
# 1942                   1933       0.011977     0.000168       0.021392  ...
#
#        sen_mes   cos_mes  t_med t_max t_min  dd_med  dd_ffx  ff_med  ff_max  \
# 1529  0.207912  0.978148    8.5  15.1   4.2    94.0   257.0     0.9     3.7
# 1530  0.207912  0.978148   15.6  18.5  11.4   223.0   180.0     5.3    15.9
# 1531  0.207912  0.978148   13.2  17.7   9.9   201.0   221.0     5.1    10.6
# 1532  0.207912  0.978148   13.6  17.4  10.0   218.0   178.0     5.4    19.8
# 1533  0.207912  0.978148   15.3  18.6  10.2   207.0   192.0     2.0    12.0
# ...        ...       ...    ...   ...   ...     ...     ...     ...     ...
# 1938  0.587785 -0.809017    8.0  10.4   3.1   127.0   132.0     1.0     4.2
# 1939  0.587785 -0.809017    7.8  13.9   4.3    80.0   121.0     1.6     4.2
# 1940  0.587785 -0.809017    2.7   3.8   1.7    78.0   104.0     1.8     6.6
# 1941  0.587785 -0.809017   10.9  14.8   6.8    50.0    84.0     2.0     5.1
# 1942  0.587785 -0.809017    9.8  12.8   8.1    30.0    28.0     1.6     4.3
#
#       pr_qtd
# 1529     2.5
# 1530    11.7
# 1531     1.7
# 1532    49.5
# 1533    16.6
# ...      ...
# 1938     0.0
# 1939     0.0
# 1940     0.1
# 1941     0.5
# 1942     0.0
#
# [414 rows x 48 columns]

# %%
df.columns
# Index(['codigo_do_relatorio', 'concelho', 'data_do_incidente',
# 'nivel_de_tensao', 'causa_do_incidente', 'duracao_incidente_min_',
# 'n_º_clientes_afetados', 'tiepi_mt_min_', 'saifi_mt_#_',
# 'saidi_mt_min_', 'end_mwh_', 'saifi_bt_#_', 'saidi_bt_min_', 'decisao',
# 'distrito', 'densidade_populacional', 'populacao_residente',
# 'setor_primario', 'setor_secundario', 'setor_terciario',
# 'indice_de_envelhecimento', 'rural', 'count_zonaa', 'count_zonab',
# 'count_zonac', 'total_concelho_zonas', 'percentagem_zonaa',
# 'percentagem_zonab', 'percentagem_zonac', 'soma_degree_rede_concelho',
# 'n_subestacoes_concelho', 'classe_da_causa_4', 'classe_da_causa_6',
# 'perc_prim', 'perc_sec', 'perc_terc', 'sen_ano', 'cos_ano', 'sen_mes',
# 'cos_mes', 't_med', 't_max', 't_min', 'dd_med', 'dd_ffx', 'ff_med',
# 'ff_max', 'pr_qtd'],
# dtype='object')
# Out:
# Index(['codigo_do_relatorio', 'concelho', 'data_do_incidente',
#        'nivel_de_tensao', 'causa_do_incidente', 'duracao_incidente_min_',
#        'n_º_clientes_afetados', 'tiepi_mt_min_', 'saifi_mt_#_',
#        'saidi_mt_min_', 'end_mwh_', 'saifi_bt_#_', 'saidi_bt_min_', 'decisao',
#        'distrito', 'densidade_populacional', 'populacao_residente',
#        'setor_primario', 'setor_secundario', 'setor_terciario',
#        'indice_de_envelhecimento', 'rural', 'count_zonaa', 'count_zonab',
#        'count_zonac', 'total_concelho_zonas', 'percentagem_zonaa',
#        'percentagem_zonab', 'percentagem_zonac', 'soma_degree_rede_concelho',
#        'n_subestacoes_concelho', 'classe_da_causa_4', 'classe_da_causa_6',
#        'perc_prim', 'perc_sec', 'perc_terc', 'sen_ano', 'cos_ano', 'sen_mes',
#        'cos_mes', 't_med', 't_max', 't_min', 'dd_med', 'dd_ffx', 'ff_med',
#        'ff_max', 'pr_qtd'],
#       dtype='object')

# %% [markdown]
# # Assumir independÊncia entre concelhos

# %%
# pegar lisboa so para exempleficar
lisboa = df[df.concelho == "LISBOA"]
# lisboa = lisboa.drop_constant_columns()
lisboa
# Out:
#      codigo_do_relatorio concelho data_do_incidente nivel_de_tensao  \
# 45    EDPD_2018_FEV_T_18   LISBOA        2018-02-15              MT
# 156   EDPD_2018_ABR_T_30   LISBOA        2018-04-11              MT
# 230   EDPD_2018_MAI_T_53   LISBOA        2018-05-26              MT
# 235   EDPD_2018_MAI_T_58   LISBOA        2018-05-28              MT
# 265   EDPD_2018_JUN_T_29   LISBOA        2018-06-21              MT
# ...                  ...      ...               ...             ...
# 2756   EDPD_2020_AGO_T_5   LISBOA        2020-08-03              MT
# 2786   EDPD_2020_SET_T_5   LISBOA        2020-09-07              BT
# 2828  EDPD_2020_SET_T_47   LISBOA        2020-09-22              MT
# 2857  EDPD_2020_OUT_T_24   LISBOA        2020-10-28              MT
# 2878  EDPD_2020_NOV_T_18   LISBOA        2020-11-13              MT
#
#      causa_do_incidente duracao_incidente_min_  n_º_clientes_afetados  \
# 45           Escavações                    107                    727
# 156          Escavações                     34                   1321
# 230          Escavações                     45                    609
# 235          Escavações                     39                    987
# 265          Escavações                     28                    737
# ...                 ...                    ...                    ...
# 2756         Escavações                     67                    336
# 2786         Escavações                    136                     77
# 2828         Escavações                     65                    571
# 2857         Escavações                     74                   2229
# 2878         Escavações                     52                    811
#
#       tiepi_mt_min_  saifi_mt_#_  saidi_mt_min_  ...   sen_mes   cos_mes  \
# 45         0.011604     0.000055       0.005689  ...  0.406737  0.913545
# 156        0.001155     0.000022       0.000645  ...  0.743145  0.669131
# 230        0.001928     0.000088       0.002022  ...  0.866025  0.500000
# 235        0.006154     0.000110       0.002359  ...  0.866025  0.500000
# 265        0.001270     0.000033       0.000700  ...  0.951057  0.309017
# ...             ...          ...            ...  ...       ...       ...
# 2756       0.010803     0.000107       0.002757  ...  0.994522 -0.104528
# 2786       0.000000     0.000000       0.000000  ...  0.951057 -0.309017
# 2828       0.009329     0.000107       0.004990  ...  0.951057 -0.309017
# 2857       0.010993     0.000097       0.005738  ...  0.866025 -0.500000
# 2878       0.004604     0.000086       0.004371  ...  0.743145 -0.669131
#
#       t_med t_max t_min  dd_med  dd_ffx  ff_med  ff_max  pr_qtd
# 45     13.4  16.5  11.0   225.0   180.0     2.7     6.8     0.0
# 156    11.4  14.6   8.2   312.0   321.0     4.2    14.0     0.8
# 230    16.9  22.0  12.7   314.0   349.0     2.0     7.8     0.0
# 235    15.7  19.5  13.5   327.0     0.0     3.9    12.8     0.0
# 265    22.5  29.1  18.6    13.0   349.0     3.1    11.5     7.1
# ...     ...   ...   ...     ...     ...     ...     ...     ...
# 2756   21.2  27.9  17.4   360.0   354.0     5.0    15.9     0.0
# 2786   27.4  36.7  20.5     2.0   354.0     2.8     8.9     0.0
# 2828   20.8  25.5  18.7   247.0   264.0     3.0    10.0     0.1
# 2857   17.6  20.6  15.5   175.0   225.0     2.1     7.7     0.8
# 2878   15.2  17.7  12.8    72.0    84.0     2.5     6.4     0.0
#
# [103 rows x 48 columns]

# %%
from eventdetector_ts import load_martian_bow_shock, FFN
from eventdetector_ts.metamodel.meta_model import MetaModel
from unidecode import unidecode
def transform_concelhos(x):
  return unidecode(x).upper().replace(' ', '-')
# transform to dataset, eventos
# first import data/dados_ipma/dados_ipma_imputado.feather
ipma = clean_names(feather.read_feather(here("data/dados_ipma/dados_ipma_imputado.feather")))
# filter > 2018
ipma = ipma[ipma.date > "2018-01-01"]
# filter to lisboa
ipma.rename(columns={"estacao": "distrito"}, inplace=True)
ipma.index = ipma.date
# add sin and pos column for year and month
ipma["sen_ano"] = np.sin(2*np.pi*ipma.index.year/12)
ipma["cos_ano"] = np.cos(2*np.pi*ipma.index.year/12)
ipma["sen_mes"] = np.sin(2*np.pi*ipma.index.month/12)
ipma["cos_mes"] = np.cos(2*np.pi*ipma.index.month/12)

ipma.drop(columns=["index", "ano", "mes", "dia", "date"], inplace=True)
ipma["distrito"] = ipma["distrito"].apply(transform_concelhos)
ipma_lisboa = ipma[ipma.distrito == "LISBOA"]
ipma_lisboa.drop(columns=["distrito"], inplace=True)
# add columns not related to the event
not_event_related = ["densidade_populacional", "populacao_residente", "setor_primario", "setor_secundario", "setor_terciario", "indice_de_envelhecimento", "rural", "count_zonaa", "count_zonab", "count_zonac", "total_concelho_zonas", "percentagem_zonaa", "percentagem_zonab", "percentagem_zonac", "soma_degree_rede_concelho", "n_subestacoes_concelho",  "perc_prim", "perc_sec", "perc_terc"]
for c in not_event_related:
  # join por ano
  ipma_lisboa[c] = 0.0
  for y in range(2018, 2023):
    # they don't change over time, only change evert year 
    ipma_lisboa.loc[ipma_lisboa.index.year == y, c] = lisboa.loc[lisboa.data_do_incidente.dt.year == y, c].values[0]

ipma_lisboa = ipma_lisboa.drop_constant_columns()
ipma_lisboa

# meta_model = MetaModel(output_dir="mex_bow_shocks", dataset=dataset, events=events, width=76, step=1,
#                        time_window=5400.0, batch_size=3000, models=[(FFN, 1)],
#                        hyperparams_ffn=(1 , 1, 20, 20, "sigmoid"))
# 
# meta_model.fit()
# Out:
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa.drop(columns=["distrito"], inplace=True)
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
# C:\Users\Plancha\AppData\Local\Temp\ipykernel_30876\3275234616.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipma_lisboa[c] = 0.0
#             t_med  t_max  t_min  dd_med  dd_ffx  ff_med  ff_max  pr_qtd  \
# date
# 2018-01-02   13.0   15.9    9.1   269.0   309.0     1.8     6.9     0.0
# 2018-01-03   14.5   17.0   12.9   284.0   309.0     2.1     6.0     0.1
# 2018-01-04   14.3   16.3   13.3   251.0   264.0     2.8     7.9     0.8
# 2018-01-05   12.4   15.1    9.1   288.0   225.0     3.6    13.9    13.2
# 2018-01-06    8.7   12.4    6.3   352.0     6.0     3.1    15.3     0.5
# ...           ...    ...    ...     ...     ...     ...     ...     ...
# 2023-12-27    7.7    9.6    5.7    64.0    84.0     3.7     7.2     0.0
# 2023-12-28    9.8   12.7    7.4    60.0    51.0     2.9     6.3     0.0
# 2023-12-29   10.0   12.0    8.7    57.0    45.0     2.7     6.1     0.0
# 2023-12-30   10.9   14.8    6.8    50.0    84.0     2.0     5.1     0.5
# 2023-12-31   11.9   14.3    8.9   298.0   304.0     1.7     6.8     1.1
#
#             dd_med_sin  dd_med_cos  ...  setor_terciario  \
# date                                ...
# 2018-01-02   -0.923447    0.383726  ...         217447.0
# 2018-01-03    0.951064    0.308994  ...         217447.0
# 2018-01-04   -0.321594    0.946878  ...         217447.0
# 2018-01-05   -0.855504    0.517796  ...         217447.0
# 2018-01-06    0.141150    0.989988  ...         217447.0
# ...                ...         ...  ...              ...
# 2023-12-27    0.920026    0.391857  ...              0.0
# 2023-12-28   -0.304811   -0.952413  ...              0.0
# 2023-12-29    0.436165    0.899867  ...              0.0
# 2023-12-30   -0.262375    0.964966  ...              0.0
# 2023-12-31    0.436138   -0.899880  ...              0.0
#
#             indice_de_envelhecimento  count_zonaa  total_concelho_zonas  \
# date
# 2018-01-02                     166.6        880.0                 880.0
# 2018-01-03                     166.6        880.0                 880.0
# 2018-01-04                     166.6        880.0                 880.0
# 2018-01-05                     166.6        880.0                 880.0
# 2018-01-06                     166.6        880.0                 880.0
# ...                              ...          ...                   ...
# 2023-12-27                       0.0          0.0                   0.0
# 2023-12-28                       0.0          0.0                   0.0
# 2023-12-29                       0.0          0.0                   0.0
# 2023-12-30                       0.0          0.0                   0.0
# 2023-12-31                       0.0          0.0                   0.0
#
#             percentagem_zonaa  soma_degree_rede_concelho  \
# date
# 2018-01-02                1.0                      130.0
# 2018-01-03                1.0                      130.0
# 2018-01-04                1.0                      130.0
# 2018-01-05                1.0                      130.0
# 2018-01-06                1.0                      130.0
# ...                       ...                        ...
# 2023-12-27                0.0                        0.0
# 2023-12-28                0.0                        0.0
# 2023-12-29                0.0                        0.0
# 2023-12-30                0.0                        0.0
# 2023-12-31                0.0                        0.0
#
#             n_subestacoes_concelho  perc_prim  perc_sec  perc_terc
# date
# 2018-01-02                    26.0   0.005131  0.089228    0.90564
# 2018-01-03                    26.0   0.005131  0.089228    0.90564
# 2018-01-04                    26.0   0.005131  0.089228    0.90564
# 2018-01-05                    26.0   0.005131  0.089228    0.90564
# 2018-01-06                    26.0   0.005131  0.089228    0.90564
# ...                            ...        ...       ...        ...
# 2023-12-27                     0.0   0.000000  0.000000    0.00000
# 2023-12-28                     0.0   0.000000  0.000000    0.00000
# 2023-12-29                     0.0   0.000000  0.000000    0.00000
# 2023-12-30                     0.0   0.000000  0.000000    0.00000
# 2023-12-31                     0.0   0.000000  0.000000    0.00000
#
# [2190 rows x 30 columns]

# %%
# remove from ipma_lisboa those
for c in not_event_related + ["sen_ano", "cos_ano", "sen_mes", "cos_mes", "t_med", "t_max", "t_min", "dd_med", "dd_ffx", "ff_med", "ff_max", "pr_qtd"]:
  try:
    lisboa = lisboa.drop(columns=[c])
  except:
    pass
lisboa = lisboa.drop_constant_columns()
lisboa
# Out:
#      codigo_do_relatorio data_do_incidente nivel_de_tensao causa_do_incidente  \
# 45    EDPD_2018_FEV_T_18        2018-02-15              MT         Escavações
# 156   EDPD_2018_ABR_T_30        2018-04-11              MT         Escavações
# 230   EDPD_2018_MAI_T_53        2018-05-26              MT         Escavações
# 235   EDPD_2018_MAI_T_58        2018-05-28              MT         Escavações
# 265   EDPD_2018_JUN_T_29        2018-06-21              MT         Escavações
# ...                  ...               ...             ...                ...
# 2756   EDPD_2020_AGO_T_5        2020-08-03              MT         Escavações
# 2786   EDPD_2020_SET_T_5        2020-09-07              BT         Escavações
# 2828  EDPD_2020_SET_T_47        2020-09-22              MT         Escavações
# 2857  EDPD_2020_OUT_T_24        2020-10-28              MT         Escavações
# 2878  EDPD_2020_NOV_T_18        2020-11-13              MT         Escavações
#
#      duracao_incidente_min_  n_º_clientes_afetados  tiepi_mt_min_  \
# 45                      107                    727       0.011604
# 156                      34                   1321       0.001155
# 230                      45                    609       0.001928
# 235                      39                    987       0.006154
# 265                      28                    737       0.001270
# ...                     ...                    ...            ...
# 2756                     67                    336       0.010803
# 2786                    136                     77       0.000000
# 2828                     65                    571       0.009329
# 2857                     74                   2229       0.010993
# 2878                     52                    811       0.004604
#
#       saifi_mt_#_  saidi_mt_min_  end_mwh_  saifi_bt_#_  saidi_bt_min_  \
# 45       0.000055       0.005689  0.833274     0.000095       0.009749
# 156      0.000022       0.000645  0.065111     0.000024       0.000596
# 230      0.000088       0.002022  0.123634     0.000006       0.000106
# 235      0.000110       0.002359  0.394570     0.000161       0.002547
# 265      0.000033       0.000700  0.086460     0.000117       0.002379
# ...           ...            ...       ...          ...            ...
# 2756     0.000107       0.002757  0.732454     0.000053       0.001487
# 2786     0.000000       0.000000  0.001000     0.000012       0.001677
# 2828     0.000107       0.004990  0.650049     0.000089       0.004560
# 2857     0.000097       0.005738  0.715156     0.000329       0.021855
# 2878     0.000086       0.004371  0.336670     0.000006       0.000284
#
#            decisao    classe_da_causa_4 classe_da_causa_6
# 45    Não Aprovado  Humanos - Acidentes             Obras
# 156   Não Aprovado  Humanos - Acidentes             Obras
# 230   Não Aprovado  Humanos - Acidentes             Obras
# 235   Não Aprovado  Humanos - Acidentes             Obras
# 265   Não Aprovado  Humanos - Acidentes             Obras
# ...            ...                  ...               ...
# 2756  Não Aprovado  Humanos - Acidentes             Obras
# 2786  Não Aprovado  Humanos - Acidentes             Obras
# 2828  Não Aprovado  Humanos - Acidentes             Obras
# 2857  Não Aprovado  Humanos - Acidentes             Obras
# 2878  Não Aprovado  Humanos - Acidentes             Obras
#
# [103 rows x 15 columns]

# %%
# TODO resto
