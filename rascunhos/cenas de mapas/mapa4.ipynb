# %%
# read geojson
import numpy as np
from pyprojroot.here import here
import pandas as pd
import geopandas as gpd

df = gpd.read_file(here("shape/adresses.geojson"))
df
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)
#                      hash number                  street unit  \
# 0        e8f7c3d68c88bb6d                    R PRINCIPAL
# 1        346001c6879948ad                 R VALE PINHOSO
# 2        d128c251aaa0bd4e                       R CENTRO
# 3        070a883f06cfa3b0              URB FONTE DO GATO
# 4        18cedd39560233a3     74       R VALE DA PORTELA
# ...                   ...    ...                     ...  ...
# 5911134  ca610742db306f43                   CAN FURNINHA
# 5911135  fcbc42fe9799cc5b                     LG CANCELA
# 5911136  bed4eb017a2c96e3                       R MATRIZ
# 5911137  75a44f2281ec861a         R JOAQUIM PEDRO COELHO
# 5911138  bb409e9b682cdf53                       R PEDRAS
#
#                        city district region  postcode  \
# 0        MACINHATA DO VOUGA                  3750-601
# 1        MACINHATA DO VOUGA                  3750-593
# ...

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.plot()
#
# File ~\Desktop\pfacd\.pixi\envs\default\Lib\site-packages\geopandas\plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\Desktop\pfacd\.pixi\envs\default\Lib\site-packages\geopandas\plotting.py:716, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     713     markersize = df[markersize].values
#     715 if column is None:
# ...

# %% [markdown]
# VER CODIGO POSTAL OUTRA VEZ AGR TUO BUE CONFUSO
